# %%
import pandas as pd
import seaborn as sns

table = pd.read_csv('aluguel.csv', sep=';')

display(table)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
pd.set_option('display.float_format', lambda x:'%.5f' %x)

table.describe()
# Out:
#           Quartos       Vagas      Suites        Area           Valor  \
# count 32960.00000 32960.00000 32960.00000 32960.00000     32943.00000
# mean      1.77139     1.74906     0.66578   231.90155     12952.65972
# std       1.71787    20.38040     1.17652  1135.25415    667521.96942
# min       0.00000     0.00000     0.00000     0.00000        75.00000
# 25%       0.00000     0.00000     0.00000    55.00000      1500.00000
# 50%       2.00000     1.00000     0.00000    87.00000      2800.00000
# 75%       3.00000     2.00000     1.00000   170.00000      6500.00000
# max     100.00000  1966.00000    70.00000 90000.00000 120000000.00000
#
#          Condominio           IPTU
# count   28867.00000    22723.00000
# mean     2388.06242     2364.40959
# std     39184.95961   179564.06290
# min         1.00000        1.00000
# 25%       590.00000      110.00000
# 50%       990.00000      250.00000
# 75%      1800.00000      697.00000
# max   6552570.00000 27053070.00000

# %%
table[table['Quartos'] == 6]
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 765                  Casa  Barra da Tijuca        6      4       6   540
# 916    Casa de Condomínio              Joá        6      4       6   550
# 1085                 Casa  Barra da Tijuca        6      1       0   425
# 1143                 Casa            Lagoa        6      1       0   750
# 1155                 Casa             Urca        6      5       5  1000
# ...                   ...              ...      ...    ...     ...   ...
# 32079      Casa Comercial            Lagoa        6      2       0   500
# 32270  Casa de Condomínio  Barra da Tijuca        6      6       6  1200
# 32458  Casa de Condomínio  Barra da Tijuca        6      4       4   662
# 32591                Casa  Barra da Tijuca        6      0       5   800
# 32656  Casa de Condomínio           Leblon        6      3       6  1206
#
#             Valor  Condominio       IPTU
# 765   25000.00000  2333.00000 2900.00000
# ...

# %%
sns.countplot(x=table['Quartos'])
# Out:
# <AxesSubplot: xlabel='Quartos', ylabel='count'>
